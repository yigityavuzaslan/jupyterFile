# %%
x=5
y=2

# %%
x>y
# Out:
# True

# %%
y>x
# Out:
# False

# %%
y=5

# %%
x>=y
# Out:
# True

# %%
x>=5.001
# Out:
# False

# %%
x=10
y=8

# %%
#x=y  #x y ye esit olur yani x=8 olur

# %%
x==y ##x,y ye esit midir sorgulamak icin
# Out:
# False

# %%
x!=y ##esit degildir
# Out:
# True

# %%
2>1 and 3>2
# Out:
# True

# %%
2>1 and 3<2 ## and,iki kosulda saglanirsa true cikarir
# Out:
# False

# %%
2>1 or 3<2 ## or,tek bir kosul saglandiginda true cevirir
# Out:
# True

# %%
not 1==1
# Out:
# False

# %%
10 in [10,20,30]  ##icinde var mi diye sorguladik
# Out:
# True

# %%
5 in [10,20,30]
# Out:
# False

# %%
10 in {10,20,30} ##setlerde ise yarar
# Out:
# True

# %%
myDictionary={"a":10,"b":20,"c":30}

# %%
10 in myDictionary
# Out:
# False

# %%
10 in myDictionary.values()
# Out:
# True

# %%
"b" in myDictionary.keys()
# Out:
# True

# %%
10 in (10,20,30) ##tuple da ise yarar
# Out:
# True

# %%
mySuperHero="Batman"

# %%
mySuperHero=="Batman"
# Out:
# True

# %%
mySuperHero=="Superman"
# Out:
# False

# %%
if mySuperHero=="Batman":    ## sadece true ise alt kismi calistirir
    print("Batman")
# Out:
# Batman

# %%
if 3>2:
    print("yigit")
# Out:
# yigit

# %%
mySuperHero=input("enter superhero:")
# Out:
# enter superhero: wonder woman

# %%
if mySuperHero=="Superman":
    print("superman")
elif mySuperHero=="Batman":
    print("batman")
elif mySuperHero=="Aquaman":
    print("aquaman")
else:                                    ##hicbiri saglanmiyorsa bunu calistirir
    print(":(")
# Out:
# :(

# %%
myAge=100

# %%
if myAge<=18:
    print("age<=18")
elif myAge>18 and myAge<=30:
    print("age 18 ile 30 arasinda")
elif myAge>30 and myAge<=40:
    print("age 30 ile 40 arasinda")
else:
    print("age>40")
# Out:
# age>40

# %%
mySuperHero=input("enter superhero:")
# Out:
# enter superhero: spiderman

# %%
mySuperheroList=["Spider Man","Iron Man","Thor","Black Widow"]

# %%
if mySuperHero in mySuperheroList:
    print(":)")
else:
    print(":(")
# Out:
# :(
