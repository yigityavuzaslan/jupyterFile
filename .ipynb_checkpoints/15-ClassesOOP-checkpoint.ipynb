# %%
yigitName="yigit"

# %%
yigitYas=90

# %%
yigitGender="Male"

# %%
yavuzName="Yavuz"

# %%
yavuzYas=10

# %%
yavuzGender="Male"

# %%
class Person():
    #property
    name=""
    age=0
    gender=""
    job=""

    ##initializer method
    def __init__(self,name,age,gender):
        self.name=name
        self.age= age
        self.gender=gender
        ##self yazinca yukaridaki degerlere esitliyoruz
    ##method
    def test(self):
        print("test")

# %%
yigit=Person("Yigit",21,"Male")

# %%
type(yigit)
# Out:
# __main__.Person

# %%
yigit.name
# Out:
# 'Yigit'

# %%
yigit.age
# Out:
# 21

# %%
yigit.gender
# Out:
# 'Male'

# %%
yigit.test()
# Out:
# test

# %%
yigit.job="data "

# %%
yigit.job
# Out:
# 'data '

# %%
class Dog():

    year=7
    
    def __init__(self,age):
        self.age=age

    def humanAge(self):
        return self.age * Dog.year  #Dog.year=self.year  #method kullanmadanda yapabilirdik

# %%
myDog=Dog(3)

# %%
myDog.age
# Out:
# 3

# %%
myDog.humanAge()
# Out:
# 21
