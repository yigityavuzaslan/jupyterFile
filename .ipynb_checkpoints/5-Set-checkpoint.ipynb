# %%
##unique elemanlar yani tekil elemanlar

# %%
myList=[10,20,30,10,20,40,10,20,40]

# %%
len(myList)
# Out:
# 9

# %%
myList
# Out:
# [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
mySet=set(myList)  ##tekil olanlari aldi sadece digerleri gitti

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet={10,20,30,10,20,40,10,20,40}  ##sozluk gibi ama degil

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(10) ##eklenmed zaten var

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(50)

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
#mySet[0] ##bu mantik bunda yok

# %%
mySet2={30,40,50,60,70}

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2
# Out:
# {30, 40, 50, 60, 70}

# %%
mySet.union(mySet2)  ##union birlestirme yapti
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
mySet.intersection(mySet2)  ##kesisenleri bulduk
# Out:
# {30, 40, 50}

# %%
countryLİst=["de","fr","tr","fr","tr","tr","de","nl","de","tr"] ##kac ulkeye sattigimizi nerden bilicez

# %%
len(countryLİst)
# Out:
# 10

# %%
len(set(countryLİst)) ##4 farkli ulkeye satmisiz
# Out:
# 4

# %%
emptyList=[]

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyList
# Out:
# [10, 20, 30]

# %%
emptySet={} ##bos set yapamioz napcaz

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet=set()

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptySet.add(10)
emptySet.add(10)
emptySet.add(20)
emptySet.add(30)

# %%
emptySet
# Out:
# {10, 20, 30}

# %%
emptyList=list()

# %%
emptyDictionary=dict()
