# %%
myList=[10,"a","b",3.14]

# %%
myList[0]
# Out:
# 10

# %%
myList[0]=100

# %%
myList
# Out:
# [100, 'a', 'b', 3.14]

# %% [markdown]
# TUPLE           ##degismesini istemedigimiz kutuphane,list vs. icin

# %%
myTuple=(10,"a","b",3.14)

# %%
myTuple
# Out:
# (10, 'a', 'b', 3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0] ##yapar
# Out:
# 10

# %%
#myTuple[0]=100  ##degisim islemlerine izin vermez

# %%
myTuple.index("a")
# Out:
# 1

# %%
resultTuple=(10,200,20)  ##degistirme kardes bunu git baska biseye ata deriz
