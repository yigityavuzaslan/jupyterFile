# %%
age = input("enter age:")
# Out:
# enter age: 35

# %%
age
# Out:
# '35'

# %%
int(age)*2
# Out:
# 70

# %%
# try - expect

# %%
while True:
    try:
        myAge=int(input("enter age:"))
        print(myAge*2)
        break
    except ValueError:
        print("enter your age!!")
# Out:
# enter age: yigit
# enter your age!!
# enter age: arda
# enter your age!!
# enter age: 35
# 70
