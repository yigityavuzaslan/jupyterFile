# %%
##key -- value eslesmesi

# %%
fruit_list=["banana","apple"]

# %%
calorie_list=[100,150]

# %%
fruit_list[0]
# Out:
# 'banana'

# %%
calorie_list[0]
# Out:
# 100

# %%
fitness_dictionary={"banana":100,"apple":150}

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
#fitness_dictionary[0] ##olmuyo,index mantigi yok

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary.keys() ##anahtarlari verir
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values() ##degerleri verir
# Out:
# dict_values([100, 150])

# %%
list(fitness_dictionary.values()) ##listeye cevirdik
# Out:
# [100, 150]

# %%
fitness_dictionary["banana"]=200

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150}

# %%
fitness_dictionary["melon"]=300 ##ekleme isi boyle

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
fitness_dictionary.get("apple",0)
# Out:
# 150

# %%
fitness_dictionary.get("appl",0) ##yanlis girilirse 0 yazsin diye
# Out:
# 0

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
my_dictionary={100:"a",200:"b",300:"c"} #str-int   ,   int--str , str--str hic farketmez

# %%
my_dictionary[100]
# Out:
# 'a'

# %%
my_mixed_dictionary={"key1":100,"key2":3.14,"key3":[10,20,30]}

# %%
my_mixed_dictionary["key3"]  ##20 degerini al burdan
# Out:
# [10, 20, 30]

# %%
my_mixed_dictionary["key3"][1]
# Out:
# 20

# %%
last_dictionary={"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}} ##200 rakamini almaya calis
##40 i almaya calis

# %%
last_dictionary["k4"]
# Out:
# {'a': 100, 'b': 200}

# %%
last_dictionary["k4"]["b"]
# Out:
# 200

# %%
last_dictionary["k2"][3]
# Out:
# 40
