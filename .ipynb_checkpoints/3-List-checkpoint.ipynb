# %%
myString="hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %% [markdown]
# LİST

# %%
myList=[10,20,30]

# %%
myList
# Out:
# [10, 20, 30]

# %%
x=10
y=20
z=30

# %%
myList=[x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
 myList[1]
# Out:
# 20

# %%
myList[0]=100  ##str de eleman degistiremezsin ama int de degistirirsin

# %%
myList
# Out:
# [100, 20, 30]

# %%
myList.append(35)

# %%
myList
# Out:
# [100, 20, 30, 35]

# %%
myList.count(20)  #kac tane 20 var
# Out:
# 1

# %%
myList.index(35) ##35 kacinci indexte
# Out:
# 3

# %%
myList.insert(2,46)  ##kacinci indexe hangi sayiyi koymak istersek koydurur

# %%
myList
# Out:
# [100, 20, 46, 30, 35]

# %%
myList.pop() ##en son elemani cikarir
# Out:
# 35

# %%
myList
# Out:
# [100, 20, 46, 30]

# %%
myList.remove(46) ##46 yi cikarmak istedik

# %%
myList
# Out:
# [100, 20, 30]

# %%
myList.reverse() ##terse cevirdi

# %%
myList
# Out:
# [100, 20, 30]

# %%
myList.sort() ##dizdi,kücükten büyüge

# %%
myList
# Out:
# [20, 30, 100]

# %%
x=input("enter x")
# Out:
# enter x 10

# %%
type(x) ##istedigimizi yazabildigimiz icin str aldi genellesin dşye
# Out:
# str

# %%
y=input("enter y")
# Out:
# enter y 20

# %%
z=input("enter z")
# Out:
# enter z 30

# %%
inputList=[]

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
inputList[1]
# Out:
# '20'

# %%
inputList[1]*2 ##str oldugu icin 2020 yazdi ama biz 40 cikmasini istiyoz nasi yapcaz
# Out:
# '2020'

# %% [markdown]
# VERİ TİPİ DONUSTURME

# %%
myInteger=50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString="40"

# %%
int(myString)  ##bunlar okey
# Out:
# 40

# %%
myString="python"

# %%
#int(myString) ## olmuyo,akla uygun deil

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
int(inputList[1])*2
# Out:
# 40

# %%
nameList=["atil","atlas","a","b"]

# %%
floadList=[3.14,2.5,10.2,100.123]

# %%
mixedList=["atil",100,3.14]  ##str int float karisik olması sorun teskil etmez

# %%
type(mixedList)
# Out:
# list

# %%
list1=[10,20,30]
list2=[40,50,60]

# %%
list1+list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1*2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
#list1/5  ##olmuyo yasak

# %%
mixedList
# Out:
# ['atil', 100, 3.14]

# %%
mixedList[1]
# Out:
# 100

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[2])
# Out:
# float

# %% [markdown]
# İC İCE LİSTELER(NESTEDLİST)

# %%
myNestedList=[10,20,3.14,"atil",[1,2,3]]

# %%
myNestedList[2]
# Out:
# 3.14

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
myNestedList[4][1] ##4.nun 1.sini aldik
# Out:
# 2

# %%
lastList=["a","b",["c","d","e"],"f"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[2]
# Out:
# ['c', 'd', 'e']

# %%
lastList[2][2]
# Out:
# 'e'

# %%
firstList=[10,20,30,40,50,60,70]

# %%
firstList[2:]
# Out:
# [30, 40, 50, 60, 70]

# %%
firstList[::2]
# Out:
# [10, 30, 50, 70]

# %%
firstList[1:6:3]
# Out:
# [20, 50]
