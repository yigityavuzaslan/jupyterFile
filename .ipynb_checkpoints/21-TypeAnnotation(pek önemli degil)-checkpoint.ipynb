# %%
name="yigit"

# %%
type(name)
# Out:
# str

# %%
name : str ="yigit"

# %%
type(name)
# Out:
# str

# %%
## hicbir sey degismedi python icin onemli degil ama dokuman okumada kolaylık olsun diye

# %%
def add_number(a,b) -> int:
    return a+b

# %%
add_number(4,5)
# Out:
# 9

# %%
def process_value(value: int | str) -> str:
    if isinstance(value,int):
        return f"processed integer: {value}"
    else:
        return f"processed string: {value}"

# %%
process_value(50)
# Out:
# 'processed integer: 50'

# %%
process_value("dasdasd")
# Out:
# 'processed string: dasdasd'
