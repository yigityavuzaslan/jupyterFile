# %%
 4*3
# Out:
# 12

# %% [markdown]
# VARİABLES BAŞLIĞI MARKDOWN

# %%
900/4
# Out:
# 225.0

# %%
900/24
# Out:
# 37.5

# %%
10-100
# Out:
# -90

# %%
age=50

# %%
##data type

# %%
type(3.14)
# Out:
# float

# %%
type(3)
# Out:
# int

# %%
pi=3.14
x=-100

# %%
x+pi
# Out:
# -96.86

# %%
type(x+pi)
# Out:
# float

# %%
myFloat = 1.34432423

# %%
type(myFloat)
# Out:
# float

# %%
#camelCase
#snake_case

# %%
40/4
# Out:
# 10.0

# %%
type(40/4)
# Out:
# float

# %%
4.0-2
# Out:
# 2.0

# %%
4.2-2
# Out:
# 2.2
