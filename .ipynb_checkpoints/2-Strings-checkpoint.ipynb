# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello python")
# Out:
# hello python

# %%
name="yigit"

# %%
type(name)
# Out:
# str

# %%
"yigit's restaurant"
# Out:
# "yigit's restaurant"

# %%
name="yigit yavuzaslan"

# %%
name.capitalize()
# Out:
# 'Yigit yavuzaslan'

# %%
x=10

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
name.count("i")
# Out:
# 2

# %%
name.count("a")
# Out:
# 3

# %%
name.upper()
# Out:
# 'YIGIT YAVUZASLAN'

# %%
x=10
y=5

# %%
x+y
# Out:
# 15

# %%
z=x+y

# %%
z
# Out:
# 15

# %%
nameUpper=name.upper()

# %%
nameUpper
# Out:
# 'YIGIT YAVUZASLAN'

# %%
len(name)
# Out:
# 16

# %%
print("yigit \nyavuzaslan")
# Out:
# yigit
# yavuzaslan

# %% [markdown]
# İNDEX

# %%
myPrint="Hello python"

# %%
myPrint
# Out:
# 'Hello python'

# %%
myPrint[4]
# Out:
# 'o'

# %%
myPrint[1]
# Out:
# 'e'

# %%
myPrint[10]
# Out:
# 'o'

# %%
len(myPrint)
# Out:
# 12

# %%
len(myPrint)-1 ##bu kaç karakter olduğunu söyler
# Out:
# 11

# %%
myName="james hetfield"  ##son harfi almaya çalış(sayarak deil)

# %%
len(myName)-1
# Out:
# 13

# %%
myName[13]
# Out:
# 'd'

# %%
myName[-1] ##böylede olabilirdi,- li yazınca sondan saymaya başlıyo
# Out:
# 'd'

# %%
barcode="ABCDE123123982"

# %%
barcode[0:3]   ##[start index:stop index:step index]
# Out:
# 'ABC'

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode[:5:]
# Out:
# 'ABCDE'

# %%
barcode[::2] ##2ser atlaya atlaya gider
# Out:
# 'ACE2138'

# %%
barcode[::-1] ##ters cevirir
# Out:
# '289321321EDCBA'

# %%
barcode.index("A") ##bu harf hangi indexde diye sormak icin
# Out:
# 0

# %%
barcode.split("3") ##ayırmak icin
# Out:
# ['ABCDE12', '12', '982']
