# %%
##2 deger alir True False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean=True

# %%
type(myBoolean)
# Out:
# bool

# %%
5<3
# Out:
# False

# %%
5>3
# Out:
# True

# %%
yas=input("yasinizi girin:")  ##yas iste ve 18 den buyuk mu bak
# Out:
# yasinizi girin: 17

# %%
int(yas)>18
# Out:
# False
